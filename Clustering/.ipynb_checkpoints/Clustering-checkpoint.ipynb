# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import silhouette_samples
import seaborn as sns
sns.set_style("whitegrid")
import matplotlib.pyplot as plt
# %matplotlib inline  
import matplotlib as mpl
from copy import deepcopy

# %% [markdown]
# ### Import data

# %%
label1 = 'overall'
label2 = 'potential'
label3 = 'age'
label4 = 'potential'

# %%
data = pd.read_csv('clustering-datasets.csv')
data2 = pd.read_csv('clustering-datasets2.csv')

# %%
data
# Out:
#        overall  potential
# 0           94         94
# 1           93         93
# 2           92         92
# 3           91         93
# 4           91         91
# ...        ...        ...
# 18273       48         56
# 18274       48         56
# 18275       48         56
# 18276       48         54
# 18277       48         51
#
# [18278 rows x 2 columns]

# %%
data2
# Out:
#        overall  age
# 0           94   32
# 1           93   34
# 2           92   27
# 3           91   26
# 4           91   28
# ...        ...  ...
# 18273       48   22
# 18274       48   22
# 18275       48   19
# 18276       48   18
# 18277       48   26
#
# [18278 rows x 2 columns]

# %%
data.describe()
# Out:
#             overall     potential
# count  18278.000000  18278.000000
# mean      66.244994     71.546887
# std        6.949953      6.139669
# min       48.000000     49.000000
# 25%       62.000000     67.000000
# 50%       66.000000     71.000000
# 75%       71.000000     75.000000
# max       94.000000     95.000000

# %%
data2.describe()
# Out:
#             overall           age
# count  18278.000000  18278.000000
# mean      66.244994     25.283291
# std        6.949953      4.656964
# min       48.000000     16.000000
# 25%       62.000000     22.000000
# 50%       66.000000     25.000000
# 75%       71.000000     29.000000
# max       94.000000     42.000000

# %% [markdown]
# ### Check for the missing values

# %%
missing_values = data.isnull().sum()
missing_values
# Out:
# overall      0
# potential    0
# dtype: int64

# %%
missing_values2 = data2.isnull().sum()
missing_values2
# Out:
# overall    0
# age        0
# dtype: int64

# %%
def boxPlot(idx1, idx2, data):
    mpl.rcParams['figure.dpi'] = 100
    plt.figure(figsize=(60, 60))
    f, axes = plt.subplots(1, 2)
    sns.boxplot(y=data[idx1], ax=axes[0])
    sns.boxplot(y=data[idx2], ax=axes[1])
    plt.subplots_adjust(wspace=1)

# %%
boxPlot(label1, label2, data)

# %%
boxPlot(label1, label3, data2)

# %% [markdown]
# #### Formula to find out upper limit and lower limit from Outliers

# %%
def setbound(datacolumn):
    sorted(datacolumn)
    Q1,Q3 = np.percentile(datacolumn , [25,75])
    IQR = Q3 - Q1
    print(Q1, Q3)
    lower_range = Q1 - (1.5 * IQR)
    upper_range = Q3 + (1.5 * IQR)
    return lower_range,upper_range

# %% [markdown]
# #### Get the outliers data

# %%
def getOutlierData(data, mainData):
    lowerbound,upperbound = setbound(data)
    return mainData[(data < lowerbound) | (data > upperbound)]

# %% [markdown]
# #### Drop the outliers data

# %%
def outliering(idx1, idx2, mainData):
    while True:
        lowerbound,upperbound = setbound(mainData[idx1])
        res1 = getOutlierData(mainData[idx1], mainData)
#         print(getOutlierData(data1, mainData))

        lowerbound,upperbound = setbound(mainData[idx2])
#         print(getOutlierData(data2, mainData))
        res2 = getOutlierData(mainData[idx2], mainData)
        
        res = pd.concat([res1,res2]).drop_duplicates()
        res = res.index

        print('Total Outliers = ',len(res))
        print('=== The Outliers ===')
        print(res)    
        mainData.drop(res, inplace=True)

        if(len(res)==0):
            break
    print("BLOXPOT AFTER OUTLIERING")
    boxPlot(idx1, idx2, mainData)
    return mainData

# %%
newData = outliering(label1, label2, data)
# Out:
# 62.0 71.0
# 62.0 71.0
# 67.0 75.0
# 67.0 75.0
# Total Outliers =  94
# === The Outliers ===
# Int64Index([    0,     1,     2,     3,     4,     6,     7,     8,    10,
#                11,    14,    16,    23,    24,    26,    27,    29,    40,
#                42,    43,    44,    55,    56,    58,    60,    62,    64,
#                73,    74,    75,    76,    80,    85,    86,    87,    96,
#             18235, 18237, 18238, 18240, 18241, 18242, 18247, 18249, 18256,
#             18258, 18260, 18262, 18264, 18271, 18272, 18273, 18276, 18277,
#               108,   110,   111,   116,   157,   158,   162,   237,   238,
#               329,   332,   411,   412,   568,   569,   571,   753,   754,
#               992,  1254,  1255,  1257,  1615,  2121,  2122,  3288,  4041,
#              4756, 17580, 17777, 17945, 17946, 18064, 18065, 18164, 18165,
#             18167, 18230, 18232, 18233],
#            dtype='int64')
# 62.0 71.0
# 62.0 71.0
# 67.0 75.0
# 67.0 75.0
# Total Outliers =  49
# === The Outliers ===
# Int64Index([    5,     9,    12,    15,    17,    25,    28,    30,    41,
#                45,    57,    59,    61,    63,    65,    77,    81,    88,
#                97, 18236, 18239, 18243, 18248, 18250, 18257, 18259, 18261,
#             18263, 18265, 18274,   109,   112,   117,   159,   163,   239,
#               330,   413,   570,   572,  1256,  2123, 17581, 17778, 17947,
#             18166, 18168, 18231, 18234],
#            dtype='int64')
# 62.0 71.0
# 62.0 71.0
# 67.0 75.0
# 67.0 75.0
# Total Outliers =  22
# === The Outliers ===
# Int64Index([   13,    18,    31,    46,    66,    78,    82,    89,    98,
#             18244, 18251, 18266, 18275,   113,   118,   160,   164,   331,
#               573, 17582, 17779, 17948],
#            dtype='int64')
# 62.0 71.0
# 62.0 71.0
# 67.0 75.0
# 67.0 75.0
# Total Outliers =  15
# === The Outliers ===
# Int64Index([19, 32, 47, 67, 79, 83, 90, 99, 18245, 18252, 18267, 114, 119, 161,
#             165],
#            dtype='int64')
# 62.0 71.0
# 62.0 71.0
# 67.0 75.0
# 67.0 75.0
# Total Outliers =  12
# === The Outliers ===
# Int64Index([20, 33, 48, 68, 84, 91, 100, 18246, 18253, 18268, 115, 166], dtype='int64')
# 62.0 71.0
# 62.0 71.0
# 67.0 75.0
# 67.0 75.0
# Total Outliers =  9
# === The Outliers ===
# Int64Index([21, 34, 49, 69, 92, 101, 18254, 18269, 167], dtype='int64')
# 62.0 71.0
# 62.0 71.0
# 67.0 75.0
# 67.0 75.0
# Total Outliers =  9
# === The Outliers ===
# Int64Index([22, 35, 50, 70, 93, 102, 18255, 18270, 168], dtype='int64')
# 62.0 71.0
# 62.0 71.0
# 67.0 75.0
# 67.0 75.0
# Total Outliers =  6
# === The Outliers ===
# Int64Index([36, 51, 71, 94, 103, 169], dtype='int64')
# 62.0 71.0
# 62.0 71.0
# 67.0 75.0
# 67.0 75.0
# Total Outliers =  6
# === The Outliers ===
# Int64Index([37, 52, 72, 95, 104, 170], dtype='int64')
# 62.0 71.0
# 62.0 71.0
# 67.0 75.0
# 67.0 75.0
# Total Outliers =  4
# === The Outliers ===
# Int64Index([38, 53, 105, 171], dtype='int64')
# 62.0 71.0
# 62.0 71.0
# 67.0 75.0
# 67.0 75.0
# Total Outliers =  3
# === The Outliers ===
# Int64Index([39, 54, 106], dtype='int64')
# 62.0 71.0
# 62.0 71.0
# 67.0 75.0
# 67.0 75.0
# Total Outliers =  1
# === The Outliers ===
# Int64Index([107], dtype='int64')
# 62.0 71.0
# 62.0 71.0
# 67.0 75.0
# 67.0 75.0
# Total Outliers =  0
# === The Outliers ===
# Int64Index([], dtype='int64')
# BLOXPOT AFTER OUTLIERING

# %%
newData2 = outliering(label1, label3, data2)
# Out:
# 62.0 71.0
# 62.0 71.0
# 22.0 29.0
# 22.0 29.0
# Total Outliers =  83
# === The Outliers ===
# Int64Index([    0,     1,     2,     3,     4,     6,     8,    10,    11,
#                12,    13,    16,    17,    18,    19,    20,    23,    24,
#                26,    27,    29,    30,    31,    36,    37,    40,    41,
#                42,    43,    44,    46,    47,    49,    52,    55,    56,
#                57,    58,    60,    62,    64,    67,    69,    72,    73,
#                74,    75,    76,    77,    78,    81,    86,    87,    92,
#                96,    97,    99,   102, 18235, 18241, 18242, 18247, 18249,
#             18260, 18273, 18277,   200,   868,  1880,  2963,  3706,  4417,
#              6235,  7230,  8359, 10665, 10702, 11832, 13003, 14527, 15812,
#             16314, 18233],
#            dtype='int64')
# 62.0 71.0
# 62.0 71.0
# 22.0 29.0
# 22.0 29.0
# Total Outliers =  35
# === The Outliers ===
# Int64Index([    5,     7,    14,    21,    25,    28,    32,    33,    38,
#                45,    48,    50,    54,    59,    61,    63,    65,    66,
#                79,    80,    82,    88,    89,    91,    94,    98, 18236,
#             18243, 18244, 18250, 18264, 18271, 18274,  2965,  4418],
#            dtype='int64')
# 62.0 71.0
# 62.0 71.0
# 22.0 29.0
# 22.0 29.0
# Total Outliers =  20
# === The Outliers ===
# Int64Index([    9,    15,    34,    35,    39,    51,    53,    68,    70,
#                83,    90,    93,   100,   101,   105, 18237, 18245, 18251,
#             18266, 18272],
#            dtype='int64')
# 62.0 71.0
# 62.0 71.0
# 22.0 29.0
# 22.0 29.0
# Total Outliers =  11
# === The Outliers ===
# Int64Index([22, 71, 84, 95, 103, 104, 106, 18238, 18246, 18257, 18270], dtype='int64')
# 62.0 71.0
# 62.0 71.0
# 22.0 29.0
# 22.0 29.0
# Total Outliers =  5
# === The Outliers ===
# Int64Index([85, 107, 18239, 18252, 18261], dtype='int64')
# 62.0 71.0
# 62.0 71.0
# 22.0 29.0
# 22.0 29.0
# Total Outliers =  3
# === The Outliers ===
# Int64Index([18240, 18253, 18262], dtype='int64')
# 62.0 71.0
# 62.0 71.0
# 22.0 29.0
# 22.0 29.0
# Total Outliers =  3
# === The Outliers ===
# Int64Index([18248, 18254, 18265], dtype='int64')
# 62.0 71.0
# 62.0 71.0
# 22.0 29.0
# 22.0 29.0
# Total Outliers =  3
# === The Outliers ===
# Int64Index([18255, 18259, 18267], dtype='int64')
# 62.0 71.0
# 62.0 71.0
# 22.0 29.0
# 22.0 29.0
# Total Outliers =  2
# === The Outliers ===
# Int64Index([18256, 18275], dtype='int64')
# 62.0 71.0
# 62.0 71.0
# 22.0 29.0
# 22.0 29.0
# Total Outliers =  1
# === The Outliers ===
# Int64Index([18258], dtype='int64')
# 62.0 71.0
# 62.0 71.0
# 22.0 29.0
# 22.0 29.0
# Total Outliers =  1
# === The Outliers ===
# Int64Index([18263], dtype='int64')
# 62.0 71.0
# 62.0 71.0
# 22.0 29.0
# 22.0 29.0
# Total Outliers =  1
# === The Outliers ===
# Int64Index([18268], dtype='int64')
# 62.0 71.0
# 62.0 71.0
# 22.0 29.0
# 22.0 29.0
# Total Outliers =  1
# === The Outliers ===
# Int64Index([18269], dtype='int64')
# 62.0 71.0
# 62.0 71.0
# 22.0 29.0
# 22.0 29.0
# Total Outliers =  1
# === The Outliers ===
# Int64Index([18276], dtype='int64')
# 62.0 71.0
# 62.0 71.0
# 22.0 29.0
# 22.0 29.0
# Total Outliers =  0
# === The Outliers ===
# Int64Index([], dtype='int64')
# BLOXPOT AFTER OUTLIERING

# %%
plt.scatter(newData[label1], newData[label2])
plt.xlabel(label1)
plt.ylabel(label2)
# Out:
# Text(0, 0.5, 'potential')

# %%
plt.scatter(newData2[label1], newData2[label3])
plt.xlabel(label1)
plt.ylabel(label3)
# Out:
# Text(0, 0.5, 'age')

# %%
k = 3

# %% [markdown]
# #### Function to generate centroids

# %%
def generateCentroids(k, data1, data2):
    # Randomize value from 0 until max of data depend on size of k
    xCentroids = np.random.randint(np.min(data1), np.max(data1), size=k)
    yCentroids = np.random.randint(np.min(data2), np.max(data2), size=k) 
    
    # Merge X and Y Centroids
    centroids = np.array(list(zip(xCentroids, yCentroids)))
    return centroids, xCentroids, yCentroids

# %% [markdown]
# ##### Generate centroids

# %%
centroids, x, y = generateCentroids(k,newData[label1],newData[label2])
centroids = sorted(centroids, key=lambda x:x[:][0], reverse=False)

centroids2, x2, y2 = generateCentroids(k,newData2[label1],newData2[label3])
centroids2 = sorted(centroids2, key=lambda y:y[:][0], reverse=False)

# %%
centroids = np.array(centroids)
centroids2 = np.array(centroids2)

# %%
centroids
# Out:
# array([[52, 67],
#        [54, 55],
#        [66, 79]])

# %%
centroids2
# Out:
# array([[62, 36],
#        [64, 18],
#        [67, 33]])

# %% [markdown]
# ##### Plot first centroids

# %%
plt.scatter(newData[label1], newData[label2], c='#050505', s=7)
plt.scatter(x, y, marker='*', s=200, c='g')

# %%
plt.scatter(newData2[label1], newData2[label3], c='#050505', s=7)
plt.scatter(x2, y2, marker='*', s=200, c='g')

# %% [markdown]
# #### Euclidean Distance Formula

# %%
def euclideanDistance(data, centroids, ax=1):
    return np.linalg.norm(data - centroids, axis=ax)

# %% [markdown]
# #### Convert data to array

# %%
npData = np.array(newData)
npData2 = np.array(newData2)

# %%
npData
# Out:
# array([[84, 87],
#        [84, 87],
#        [84, 86],
#        ...,
#        [49, 56],
#        [49, 55],
#        [49, 55]], dtype=int64)

# %%
npData2
# Out:
# array([[84, 19],
#        [84, 20],
#        [84, 22],
#        ...,
#        [49, 25],
#        [49, 21],
#        [49, 28]], dtype=int64)

# %% [markdown]
# #### Formula to update centroids based on the data

# %%
def updateCentroids(idx, clusters, data):
    points = np.array([data[j] for j in range(len(data)) if clusters[j] == idx])
    return points

# %% [markdown]
# ## K-Means Function

# %%
def kMeans(k, data, centroids):
    # Set all cluster to 0
    clusters = np.zeros(len(data))
    clusters
    
    # assign old centroid as 0
    oldCentroid = np.zeros(centroids.shape)
    print("INITIALIZE CENTROIDS ", oldCentroid)
    
    # Error func. - Distance between new centroids and old centroids
    error = euclideanDistance(centroids, oldCentroid,None)
    print("INITIALIZE ERROR ", error)
    
    idx=0
    while error != 0:
        # Assigning each value to its closest cluster
        for i in range(len(data)):
            distances = euclideanDistance(data[i], centroids)
            cluster = np.argmin(distances)
            clusters[i] = cluster
            
        # Storing the old centroid values
        oldCentroid = deepcopy(centroids)
        
        # Finding the new centroids by taking the average value
        for i in range(k):
            points = updateCentroids(i,clusters, data) #[data[j] for j in range(len(data)) if clusters[j] == i]
            centroids[i] = np.mean(points, axis=0)
        error = euclideanDistance(centroids, oldCentroid, None)
        
    return centroids, clusters

# %%
lastCentroids, clusters = kMeans(k, npData, centroids)
# Out:
# INITIALIZE CENTROIDS  [[0. 0.]
#  [0. 0.]
#  [0. 0.]]
# INITIALIZE ERROR  154.04869360043273

# %%
lastCentroids2, clusters2 = kMeans(k, npData2, centroids2)
# Out:
# INITIALIZE CENTROIDS  [[0. 0.]
#  [0. 0.]
#  [0. 0.]]
# INITIALIZE ERROR  123.03657992645927

# %%
lastCentroids
# Out:
# array([[63, 68],
#        [55, 64],
#        [71, 76]])

# %%
lastCentroids2
# Out:
# array([[64, 25],
#        [56, 20],
#        [72, 27]])

# %%
clusters
# Out:
# array([2., 2., 2., ..., 1., 1., 1.])

# %%
clusters2
# Out:
# array([2., 2., 2., ..., 1., 1., 1.])

# %% [markdown]
# ### The clustering result

# %%
def finalPlot(clusters, data, centroids):
    colors = ['r', 'gray', 'cyan','b', 'y', 'c', 'm', 'pink']
    fig, ax = plt.subplots()
    for i in range(k):
            points = updateCentroids(i, clusters, data)
            ax.scatter(points[:, 0], points[:, 1], c=colors[i])

    plt.scatter(centroids[:, 0], centroids[:, 1], marker='*', s=100, c='#050505')

# %%
finalPlot(clusters, npData, lastCentroids)

# %%
finalPlot(clusters2, npData2, lastCentroids2)

# %% [markdown]
# #### Evaluatin model using Silhouette Coefficient

# %%
silhouette_samples(npData, clusters, metric='euclidean')
# Out:
# array([0.39788417, 0.39788417, 0.40651133, ..., 0.41907245, 0.40154755,
#        0.40154755])

# %%
silhouette_samples(npData2, clusters2, metric='euclidean')
# Out:
# array([0.28812101, 0.30654114, 0.34155898, ..., 0.40435744, 0.50896065,
#        0.29833027])

# %% [markdown]
# ## Kesimpulan

# %% [markdown]
# Dari hasil evaluasi, didapatkan hasil clustering yang lumayan baik dilihat dari nilai <i>silhouette coefficient</i> antar tetangga ada yang mirip

# %% [markdown]
# <p>Copyright &copy; 2020 <a href=https://www.linkedin.com/in/pratamays/>Pratama Yoga Santosa</a> </p>
