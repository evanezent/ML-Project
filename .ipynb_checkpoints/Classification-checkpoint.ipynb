# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.externals import joblib
# Out:
# C:\Users\ASUS\Anaconda3\lib\site-packages\sklearn\externals\joblib\__init__.py:15: FutureWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=FutureWarning)

# %%
data = pd.read_csv('classification-datasets.csv')

# %%
data.describe()
# Out:
#           height_cm     weight_kg
# count  18278.000000  18278.000000
# mean     181.362184     75.276343
# std        6.756961      7.047744
# min      156.000000     50.000000
# 25%      177.000000     70.000000
# 50%      181.000000     75.000000
# 75%      186.000000     80.000000
# max      205.000000    110.000000

# %%
data
# Out:
#        height_cm  weight_kg body_type
# 0            170         72    Normal
# 1            187         83    Normal
# 2            175         68      Lean
# 3            188         87    Normal
# 4            175         74    Normal
# ...          ...        ...       ...
# 18273        186         79    Normal
# 18274        177         66    Normal
# 18275        186         75      Lean
# 18276        185         74      Lean
# 18277        182         78    Normal
#
# [18278 rows x 3 columns]

# %% [markdown]
# Cek apakah ada missing value pada data

# %%
missing_values = data.isnull().sum()
missing_values
# Out:
# height_cm    0
# weight_kg    0
# body_type    0
# dtype: int64

# %%
import seaborn as sns
sns.set_style("whitegrid")
import matplotlib.pyplot as plt
# %matplotlib inline  
import matplotlib as mpl

# %%
def boxPlot(data1, data2):
    mpl.rcParams['figure.dpi'] = 100
    plt.figure(figsize=(60, 60))
    f, axes = plt.subplots(1, 2)
    sns.boxplot(y=data1, ax=axes[0])
    sns.boxplot(y=data2, ax=axes[1])
    plt.subplots_adjust(wspace=1)

# %%
boxPlot(data["height_cm"], data["weight_kg"])

# %%
def setbound(datacolumn):
    sorted(datacolumn)
    Q1,Q3 = np.percentile(datacolumn , [25,75])
    IQR = Q3 - Q1
    print(Q1, Q3)
    lower_range = Q1 - (1.5 * IQR)
    upper_range = Q3 + (1.5 * IQR)
    return lower_range,upper_range

# %%
def getOutlierData(data, mainData):
    lowerbound,upperbound = setbound(data)
    return mainData[(data < lowerbound) | (data > upperbound)]

# %%
def outliering(data1, data2, mainData):
    while True:
        lowerbound,upperbound = setbound(data1)
        res1 = getOutlierData(data1, mainData)
#         print(getOutlierData(data1, mainData))

        lowerbound,upperbound = setbound(data2)
#         print(getOutlierData(data2, mainData))
        res2 = getOutlierData(data2, mainData)
        
        res = pd.concat([res1,res2]).drop_duplicates()
        res = res.index

        print('Total Outliers = ',len(res))
        print('=== The Outliers ===')
        print(res)    
        mainData.drop(res, inplace=True)

        if(len(res)==0):
            break
    print("BLOXPOT AFTER OUTLIERING")
    boxPlot(mainData['height_cm'], mainData['weight_kg'])
    return mainData

# %%
newData = outliering(data["height_cm"], data["weight_kg"], data)
# Out:
# 177.0 186.0
# 177.0 186.0
# 70.0 80.0
# 70.0 80.0
# Total Outliers =  127
# === The Outliers ===
# Int64Index([   54,   355,   393,   628,   776,   909,  1352,  1496,  1834,
#              1923,
#             ...
#             11945, 12666, 13070, 13254, 13576, 15064, 16695, 17158, 17612,
#             17772],
#            dtype='int64', length=127)
# 177.0 186.0
# 177.0 186.0
# 70.0 80.0
# 70.0 80.0
# Total Outliers =  24
# === The Outliers ===
# Int64Index([ 4243,  5060,  6715,  7554,  7648, 10661, 11484, 11759, 12549,
#             15805, 16268, 16492, 16664, 17587, 18103,   165,  5843,  8587,
#             10665, 11965, 13201, 17022, 17078, 17817],
#            dtype='int64')
# 177.0 186.0
# 177.0 186.0
# 70.0 80.0
# 70.0 80.0
# Total Outliers =  3
# === The Outliers ===
# Int64Index([12880, 14546, 16660], dtype='int64')
# 177.0 186.0
# 177.0 186.0
# 70.0 80.0
# 70.0 80.0
# Total Outliers =  0
# === The Outliers ===
# Int64Index([], dtype='int64')
# BLOXPOT AFTER OUTLIERING
# ...

# %%
newData
# Out:
#        height_cm  weight_kg body_type
# 0            170         72    Normal
# 1            187         83    Normal
# 2            175         68      Lean
# 3            188         87    Normal
# 4            175         74    Normal
# ...          ...        ...       ...
# 18273        186         79    Normal
# 18274        177         66    Normal
# 18275        186         75      Lean
# 18276        185         74      Lean
# 18277        182         78    Normal
#
# [18124 rows x 3 columns]

# %%
mpl.rcParams['figure.dpi'] = 150
plt.figure(figsize=(100, 100))
df_nona= newData[newData['weight_kg'].notnull()]
g = sns.pairplot(df_nona[['height_cm', 'weight_kg']] )

# %%
# data_train = np.array([data['height_cm'],data['weight_kg']])
data_train = []
data_train
# Out:
# []

# %% [markdown]
# Mengambil Independen Data

# %%
for item in newData.values:
#     print(item[1])
    data_train.append([item[0], item[1]])
data_train
# Out:
# [[170, 72],
#  [187, 83],
#  [175, 68],
#  [188, 87],
#  [175, 74],
#  [181, 70],
#  [187, 85],
#  [193, 92],
#  [172, 66],
#  [175, 71],
#  [178, 73],
#  [187, 89],
#  [188, 89],
#  [191, 91],
#  [192, 82],
#  [168, 72],
#  [187, 85],
#  [173, 70],
#  [184, 82],
#  [182, 86],
#  [184, 80],
#  [189, 76],
#  [176, 73],
#  [177, 75],
#  [191, 84],
#  [188, 86],
#  [170, 69],
#  [181, 76],
#  [194, 85],
#  [193, 92],
#  [193, 92],
#  [188, 82],
#  [173, 67],
#  [185, 77],
#  [187, 78],
#  [183, 76],
#  [180, 71],
#  [187, 80],
#  [175, 69],
#  [189, 85],
#  [173, 64],
#  [185, 84],
#  [183, 78],
#  [179, 67],
#  [183, 82],
#  [185, 81],
#  [189, 86],
#  [169, 61],
#  [191, 94],
#  [186, 81],
#  [170, 68],
#  [174, 70],
#  [185, 80],
#  [183, 75],
#  [183, 75],
#  [187, 80],
#  [165, 60],
#  [182, 75],
#  [195, 90],
#  [176, 73],
#  [176, 79],
#  [181, 76],
#  [184, 78],
#  [178, 72],
#  [180, 69],
#  [190, 85],
#  [172, 68],
#  [182, 74],
#  [186, 75],
#  [185, 85],
#  [175, 73],
# ...

# %%
train = np.array(data_train)
len(train)
# Out:
# 18124

# %% [markdown]
# Mengambil Dependen Data

# %%
label = np.array(newData['body_type'])
len(label)
# Out:
# 18124

# %% [markdown]
# ### Split the Dataset

# %%
#split dataset 80% dan 20% secara random tiap 777 data
x_train, x_test, y_train, y_test = train_test_split(train, label, test_size = 0.2, random_state = 100)

# %% [markdown]
# ## Naive Bayes

# %%
from sklearn.naive_bayes import CategoricalNB

# %%
classifier = CategoricalNB()
classifier.fit(x_train, y_train)
# Out:
# CategoricalNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
hasil = classifier.predict(x_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, hasil))
# Out:
#               precision    recall  f1-score   support
#
#         Lean       0.50      0.32      0.39      1343
#       Normal       0.61      0.81      0.69      2088
#       Stocky       0.00      0.00      0.00       194
#
#     accuracy                           0.58      3625
#    macro avg       0.37      0.38      0.36      3625
# weighted avg       0.54      0.58      0.55      3625
# C:\Users\ASUS\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ##### Saving Naive Bayes Model

# %%
joblib.dump(classifier, "classification-NB.h5")
# Out:
# ['classification-NB.h5']

# %% [markdown]
# ### Kesimpulan
# Dari data di atas, didapatkan bahwa menggunakan metode Naive Bayes mendapatkan akurasi mencapai 59%

# %% [markdown]
# ## SVM

# %%
from sklearn import svm

# %%
classifier2 = svm.SVC(decision_function_shape='ovo')
classifier2.fit(x_train, y_train)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovo', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
hasil2 = classifier2.predict(x_test)

# %%
print(classification_report(y_test, hasil2))
# Out:
#               precision    recall  f1-score   support
#
#         Lean       0.64      0.28      0.39      1343
#       Normal       0.62      0.90      0.73      2088
#       Stocky       0.00      0.00      0.00       194
#
#     accuracy                           0.62      3625
#    macro avg       0.42      0.39      0.37      3625
# weighted avg       0.59      0.62      0.57      3625
# C:\Users\ASUS\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
joblib.dump(classifier2, "classification-SVM.h5")
# Out:
# ['classification-SVM.h5']

# %% [markdown]
# ### Kesimpulan
# Dari data di atas, didapatkan bahwa menggunakan metode SVM mendapatkan akurasi mencapai 63%

# %% [markdown]
# <p>Copyright &copy; 2020 <a href=https://www.linkedin.com/in/pratamays/>Pratama Yoga Santosa</a> </p>
