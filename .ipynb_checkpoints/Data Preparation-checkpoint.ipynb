# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
data = pd.read_csv("fifa20.csv")

# %%
data
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3         200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4         183277  https://sofifa.com/player/183277/eden-hazard/2...
# ...          ...                                                ...
# 18273     245006  https://sofifa.com/player/245006/shuai-shao/20...
# 18274     250995  https://sofifa.com/player/250995/mingjie-xiao/...
# 18275     252332  https://sofifa.com/player/252332/wei-zhang/20/...
# 18276     251110  https://sofifa.com/player/251110/haijian-wang/...
# 18277     233449  https://sofifa.com/player/233449/ximing-pan/20...
#
#               short_name                            long_name  age        dob  \
# ...

# %%
data.groupby("body_type").count()
# Out:
#            sofifa_id  player_url  short_name  long_name    age    dob  \
# body_type
# Akinfenwa          1           1           1          1      1      1
# Lean            6506        6506        6506       6506   6506   6506
# Normal         10753       10753       10753      10753  10753  10753
# Stocky          1018        1018        1018       1018   1018   1018
#
#            height_cm  weight_kg  nationality   club  ...   lwb   ldm   cdm  \
# body_type                                            ...
# Akinfenwa          1          1            1      1  ...     1     1     1
# Lean            6506       6506         6506   6506  ...  6044  6044  6044
# Normal         10753      10753        10753  10753  ...  9296  9296  9296
# Stocky          1018       1018         1018   1018  ...   901   901   901
#
#             rdm   rwb    lb   lcb    cb   rcb    rb
# body_type
# Akinfenwa     1     1     1     1     1     1     1
# Lean       6044  6044  6044  6044  6044  6044  6044
# ...

# %%
data.describe()
# Out:
#            sofifa_id           age     height_cm     weight_kg       overall  \
# count   18278.000000  18278.000000  18278.000000  18278.000000  18278.000000
# mean   219738.864482     25.283291    181.362184     75.276343     66.244994
# std     27960.200461      4.656964      6.756961      7.047744      6.949953
# min       768.000000     16.000000    156.000000     50.000000     48.000000
# 25%    204445.500000     22.000000    177.000000     70.000000     62.000000
# 50%    226165.000000     25.000000    181.000000     75.000000     66.000000
# 75%    240795.750000     29.000000    186.000000     80.000000     71.000000
# max    252905.000000     42.000000    205.000000    110.000000     94.000000
#
#           potential     value_eur       wage_eur  international_reputation  \
# count  18278.000000  1.827800e+04   18278.000000              18278.000000
# mean      71.546887  2.484038e+06    9456.942773                  1.103184
# ...

# %%
import seaborn as sns
sns.set_style("whitegrid")

# %% [markdown]
# ### Melihat korelasi antar data

# %%
corr = data.select_dtypes(include = ['float64', 'int64']).iloc[:, :].corr()
plt.figure(figsize=(10, 10))
ax = sns.heatmap(corr, vmax=1, square=True)
# ax.set_xticklabels(rotation=30)
plt.xticks(rotation=45)
plt.yticks(rotation=45)
# Out:
# (array([ 0.5,  2.5,  4.5,  6.5,  8.5, 10.5, 12.5, 14.5, 16.5, 18.5, 20.5,
#         22.5, 24.5, 26.5, 28.5, 30.5, 32.5, 34.5, 36.5, 38.5, 40.5, 42.5,
#         44.5, 46.5, 48.5, 50.5, 52.5, 54.5, 56.5, 58.5, 60.5]),
#  <a list of 31 Text yticklabel objects>)

# %%
corr
# Out:
#                          sofifa_id       age  height_cm  weight_kg   overall  \
# sofifa_id                 1.000000 -0.736680  -0.093464  -0.203620 -0.445061
# age                      -0.736680  1.000000   0.081391   0.237169  0.464305
# height_cm                -0.093464  0.081391   1.000000   0.768816  0.039945
# weight_kg                -0.203620  0.237169   0.768816   1.000000  0.156522
# overall                  -0.445061  0.464305   0.039945   0.156522  1.000000
# ...                            ...       ...        ...        ...       ...
# goalkeeping_diving       -0.113073  0.110313   0.367433   0.342329 -0.013239
# goalkeeping_handling     -0.116270  0.112929   0.367163   0.343211 -0.013716
# goalkeeping_kicking      -0.114658  0.112615   0.364992   0.339805 -0.017393
# goalkeeping_positioning  -0.123064  0.121381   0.367097   0.344397 -0.006408
# goalkeeping_reflexes     -0.113487  0.111811   0.367375   0.343126 -0.012775
#
# ...

# %% [markdown]
# I slice the data because I curious with the correlation of this data

# %%
data2 = pd.DataFrame(data, columns=['value_eur', 'age', 'wage_eur', 'overall', 'potential'])
corr2 = data2.select_dtypes(include = ['float64', 'int64']).iloc[:, :].corr()
corr2
# Out:
#            value_eur       age  wage_eur   overall  potential
# value_eur   1.000000  0.081513  0.858052  0.638230   0.580868
# age         0.081513  1.000000  0.151031  0.464305  -0.262872
# wage_eur    0.858052  0.151031  1.000000  0.573578   0.475490
# overall     0.638230  0.464305  0.573578  1.000000   0.646650
# potential   0.580868 -0.262872  0.475490  0.646650   1.000000

# %% [markdown]
# ## Pemotongan Data

# %% [markdown]
# <h4>Data untuk <b>Body Type</b> <i>Classification</i> berdasarkan <b>Height</b> dan <b>Weight</b></h4>

# %%
csv_clas = pd.DataFrame(data, columns=['height_cm', 'weight_kg', 'body_type'])
csv_clas
# Out:
#        height_cm  weight_kg body_type
# 0            170         72    Normal
# 1            187         83    Normal
# 2            175         68      Lean
# 3            188         87    Normal
# 4            175         74    Normal
# ...          ...        ...       ...
# 18273        186         79    Normal
# 18274        177         66    Normal
# 18275        186         75      Lean
# 18276        185         74      Lean
# 18277        182         78    Normal
#
# [18278 rows x 3 columns]

# %% [markdown]
# ##### Menyimpan Classification dataset

# %%
csv_clas.to_csv("Classification/classification-datasets.csv", index=False)

# %% [markdown]
# <h4>Data untuk <i>Clustering</i> berdasarkan Nilai <b>Overall</b> dan Nilai <b>Potential</b></h4>

# %%
csv_clus = pd.DataFrame(data, columns=['overall', 'potential'])
csv_clus
# Out:
#        overall  potential
# 0           94         94
# 1           93         93
# 2           92         92
# 3           91         93
# 4           91         91
# ...        ...        ...
# 18273       48         56
# 18274       48         56
# 18275       48         56
# 18276       48         54
# 18277       48         51
#
# [18278 rows x 2 columns]

# %% [markdown]
# ##### Menyimpan Clustering dataset

# %%
csv_clus.to_csv("Clustering/clustering-datasets.csv", index=False)

# %%
csv_clus2 = pd.DataFrame(data, columns=['overall', 'value_eur'])
csv_clus2
# Out:
#        overall  value_eur
# 0           94   95500000
# 1           93   58500000
# 2           92  105500000
# 3           91   77500000
# 4           91   90000000
# ...        ...        ...
# 18273       48      40000
# 18274       48      40000
# 18275       48      40000
# 18276       48      40000
# 18277       48      40000
#
# [18278 rows x 2 columns]

# %%
csv_clus2.to_csv("Clustering/clustering-datasets2.csv", index=False)

# %% [markdown]
# <b>After all data is exported to csv, <span style="color : red">move the dataset to every task folder</span></b>
